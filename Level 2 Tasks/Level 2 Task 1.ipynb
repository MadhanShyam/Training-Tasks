# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = ['jan','feb','mar','apr','may']
y = [2000, 4000, 1000, 8000, 6500]
plt.plot(x,y)
plt.xlabel('MONTH')
plt.ylabel('EXPENSE')
plt.title('MY EXPENSE')
plt.grid()
plt.show()
